# %%
import pandas as pd

# %%
#df = pd.read_csv("TippingModel_twitter_results_eigenvalue.csv").rename(columns={"Unnamed: 0": "T"})
df = pd.read_csv("Verona_SIR_twitter_results_eigenvalue.csv").rename(columns={"Unnamed: 0": "T"})
df
# Out:
#          T   S  I  R  run  beta     seed
# 0        0  36  0  0    0   0.5   lowest
# 1        1  35  0  1    0   0.5   lowest
# 2        2  35  0  1    0   0.5   lowest
# 3        3  35  0  1    0   0.5   lowest
# 4        4  35  0  1    0   0.5   lowest
# ...    ...  .. .. ..  ...   ...      ...
# 45295  146  32  0  4   99   0.5  highest
# 45296  147  32  0  4   99   0.5  highest
# 45297  148  32  0  4   99   0.5  highest
# 45298  149  32  0  4   99   0.5  highest
# 45299  150  32  0  4   99   0.5  highest
#
# [45300 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig, axs = plt.subplots(ncols=3, figsize=(18,4))
for i, beta in enumerate(df["beta"].unique()):
    sns.lineplot(data=df[df["beta"]==beta], 
        x="T", 
        y="R", 
        hue="seed", ax=axs[i])
    axs[i].set(xlim=(0,30))
    #axs[i].set(ylim=(0,81000))
    axs[i].set_title(f"beta = {beta}")
# Out:
# /home/petra/miniconda3/envs/core/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/petra/miniconda3/envs/core/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/petra/miniconda3/envs/core/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
